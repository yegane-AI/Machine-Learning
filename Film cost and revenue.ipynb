# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
data.describe()
# Out:
#        Production_budget_USD  Worldwide_gross_USD
# count           4.205000e+03         4.205000e+03
# mean            4.208225e+07         5.595031e+07
# std             4.487694e+07         7.606810e+07
# min             5.000000e+06         3.880000e+02
# 25%             1.300000e+07         1.072439e+07
# 50%             2.600000e+07         3.201158e+07
# 75%             5.300000e+07         6.968838e+07
# max             4.250000e+08         9.366622e+08

# %%
X = DataFrame(data, columns=['Production_budget_USD'])
y = DataFrame(data, columns=['Worldwide_gross_USD'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y,alpha=0.3)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,900000000)
plt.xlim(0,500000000)
plt.show()
